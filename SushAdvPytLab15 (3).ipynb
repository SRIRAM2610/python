# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the Axes.

# %%
#Depending on environment you are working in, plt.show() can be left out.
fig, ax = plt.subplots()            
ax.plot([4,3,2,1], [1, 4, 2, 3]) 
plt.show()                           # Show the figure.

# %%
fig = plt.figure()             # an empty figure with no Axes
fig, ax = plt.subplots()       # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
jonsnow = np.asarray(Image.open('/home/matlab/download.jpeg/'))
print(repr(jonsnow))
# Out:
# array([[[ 76,  78,  90],
#         [ 75,  77,  89],
#         [ 75,  77,  89],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]],
#
#        [[ 75,  77,  89],
#         [ 75,  77,  89],
#         [ 74,  76,  88],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]],
#
#        [[ 75,  77,  89],
#         [ 75,  77,  89],
#         [ 74,  76,  88],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]],
#
#        ...,
#
#        [[117, 124, 140],
#         [118, 125, 141],
#         [120, 127, 143],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]],
#
#        [[109, 116, 132],
#         [110, 117, 133],
#         [112, 119, 135],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]],
#
#        [[104, 111, 127],
#         [105, 112, 128],
#         [107, 114, 130],
#         ...,
#         [185, 188, 193],
#         [185, 188, 193],
#         [185, 188, 193]]], dtype=uint8)

# %%
imgplot = plt.imshow(jonsnow)

# %%
im = np.asarray(Image.open('/home/matlab/Downloads/images.jpeg'))
print(repr(im))
# Out:
# array([[[185, 140,  81],
#         [182, 141,  79],
#         [180, 139,  75],
#         ...,
#         [109, 104,   2],
#         [109, 104,   2],
#         [109, 104,   2]],
#
#        [[185, 141,  78],
#         [182, 141,  77],
#         [180, 140,  71],
#         ...,
#         [109, 104,   2],
#         [109, 104,   2],
#         [109, 104,   2]],
#
#        [[185, 142,  74],
#         [182, 142,  72],
#         [180, 140,  68],
#         ...,
#         [109, 104,   2],
#         [109, 104,   2],
#         [109, 104,   2]],
#
#        ...,
#
#        [[108,  95,   0],
#         [126, 115,  10],
#         [127, 118,  17],
#         ...,
#         [129, 111,   0],
#         [129, 111,   0],
#         [129, 111,   0]],
#
#        [[118, 107,   1],
#         [122, 111,   6],
#         [116, 107,   6],
#         ...,
#         [129, 111,   0],
#         [130, 112,   0],
#         [130, 112,   0]],
#
#        [[121, 110,   5],
#         [112, 103,   0],
#         [105,  97,   0],
#         ...,
#         [130, 112,   0],
#         [130, 112,   0],
#         [130, 112,   0]]], dtype=uint8)

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img)

# %%
pip install numpy matplotlib Pillow
# Out:
# Requirement already satisfied: numpy in /home/software/software/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/software/software/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: Pillow in /home/software/software/lib/python3.12/site-packages (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/software/software/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/software/software/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
img = Image.open('/home/matlab/Downloads/images.jpeg')
img.thumbnail((64, 64))  # resizes image in-place
imgplot = plt.imshow(img)

# %%
# Import necessary libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# --- 1. Load and display the original image ---
# Load the image and convert it to a NumPy array.
# The `with` statement handles closing the file automatically.
try:
    with Image.open('/home/matlab/Downloads/images.jpeg') as img:
        im = np.asarray(img)
except FileNotFoundError:
    print("Error: The image file was not found. Please check the file path.")
    exit()

# Create a new figure and a single subplot for the original image
fig, ax = plt.subplots(figsize=(8, 6))
ax.imshow(im)
ax.set_title('Original Bug Image')
ax.axis('off')  # Hide the axes for a cleaner image display

# --- 2. Create plots for individual color channels ---
# This visualizes the red, green, and blue components of the image.
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5))

# Red channel
red_channel = im[:, :, 0]
ax1.imshow(red_channel, cmap='Reds_r')
ax1.set_title('Red Channel')
ax1.axis('off')

# Green channel
green_channel = im[:, :, 1]
ax2.imshow(green_channel, cmap='Greens_r')
ax2.set_title('Green Channel')
ax2.axis('off')

# Blue channel
blue_channel = im[:, :, 2]
ax3.imshow(blue_channel, cmap='Blues_r')
ax3.set_title('Blue Channel')
ax3.axis('off')

fig.suptitle('Individual Color Channels', fontsize=16)


# --- 3. Create an image with an alternative color map ---
# Change the color map to emphasize different features.
fig, ax = plt.subplots(figsize=(8, 6))
# Display the red channel with a 'hot' color map
ax.imshow(red_channel, cmap='hot')
ax.set_title('Image with "Hot" Color Map')
ax.axis('off')

# --- 4. Create a histogram of pixel intensity ---
# A histogram is a great way to visualize the distribution of colors.
fig, ax = plt.subplots(figsize=(8, 6))
# ravel() flattens the multi-dimensional array into a 1D array
ax.hist(im.ravel(), bins=256, color='gray', alpha=0.7)
ax.set_title('Pixel Intensity Histogram')
ax.set_xlabel('Pixel Intensity')
ax.set_ylabel('Frequency')
ax.grid(True)

# --- 5. Display all plots ---
# This is the command you were missing. It displays all the figures created.
plt.tight_layout() # Adjusts subplot params for a tight layout
plt.show()

# %% [markdown]
# # with B&W u will get the crct distribution of pixels

# %%
# Import necessary libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Define the image path
image_path = '/home/matlab/Downloads/images.jpeg'

# --- 1. Open the color image ---
try:
    # Open the original color image
    img_color = Image.open(image_path)
except FileNotFoundError:
    print("Error: The image file was not found. Please check the file path.")
    exit()

# --- 2. Convert to a black and white (grayscale) image ---
# The 'L' mode converts the image to grayscale, using one channel (luminance).
img_grayscale = img_color.convert('L')
im_grayscale_array = np.asarray(img_grayscale)

# --- 3. Display the grayscale image and its histogram ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Display the grayscale image
ax1.imshow(im_grayscale_array, cmap='gray')
ax1.set_title('Grayscale Bug Image')
ax1.axis('off')  # Hide axes for cleaner image display

# Plot the histogram for the grayscale image
ax2.hist(im_grayscale_array.ravel(), bins=256, range=[0, 256], color='k', alpha=0.7)
ax2.set_title('Grayscale Pixel Intensity Histogram')
ax2.set_xlabel('Pixel Intensity (0=Black, 255=White)')
ax2.set_ylabel('Frequency (Number of Pixels)')
ax2.grid(True)

plt.tight_layout() # Adjusts subplot params for a tight layout
plt.show()

# %% [markdown]
# # 2nd Trail with more Pixel Pic

# %%
img = Image.open('/home/matlab/Downloads/bug.jpg')
imgplot = plt.imshow(img)

# %%
img = Image.open('/home/matlab/Downloads/bug.jpg')
img.thumbnail((64, 64))  # resizes image in-place
imgplot = plt.imshow(img)

# %%
# Import necessary libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# --- 1. Load and display the original image ---
# Load the image and convert it to a NumPy array.
# The `with` statement handles closing the file automatically.
try:
    with Image.open('/home/matlab/Downloads/bug.jpg') as img:
        im = np.asarray(img)
except FileNotFoundError:
    print("Error: The image file was not found. Please check the file path.")
    exit()

# Create a new figure and a single subplot for the original image
fig, ax = plt.subplots(figsize=(8, 6))
ax.imshow(im)
ax.set_title('Original Bug Image')
ax.axis('off')  # Hide the axes for a cleaner image display

# --- 2. Create plots for individual color channels ---
# This visualizes the red, green, and blue components of the image.
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5))

# Red channel
red_channel = im[:, :, 0]
ax1.imshow(red_channel, cmap='Reds_r')
ax1.set_title('Red Channel')
ax1.axis('off')

# Green channel
green_channel = im[:, :, 1]
ax2.imshow(green_channel, cmap='Greens_r')
ax2.set_title('Green Channel')
ax2.axis('off')

# Blue channel
blue_channel = im[:, :, 2]
ax3.imshow(blue_channel, cmap='Blues_r')
ax3.set_title('Blue Channel')
ax3.axis('off')

fig.suptitle('Individual Color Channels', fontsize=16)


# --- 3. Create an image with an alternative color map ---
# Change the color map to emphasize different features.
fig, ax = plt.subplots(figsize=(8, 6))
# Display the red channel with a 'hot' color map
ax.imshow(red_channel, cmap='hot')
ax.set_title('Image with "Hot" Color Map')
ax.axis('off')

# --- 4. Create a histogram of pixel intensity ---
# A histogram is a great way to visualize the distribution of colors.
fig, ax = plt.subplots(figsize=(8, 6))
# ravel() flattens the multi-dimensional array into a 1D array
ax.hist(im.ravel(), bins=256, color='gray', alpha=0.7)
ax.set_title('Pixel Intensity Histogram')
ax.set_xlabel('Pixel Intensity')
ax.set_ylabel('Frequency')
ax.grid(True)

# --- 5. Display all plots ---
# This is the command you were missing. It displays all the figures created.
plt.tight_layout() # Adjusts subplot params for a tight layout
plt.show()

# %% [markdown]
# # With B&W image

# %%
# Import necessary libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Define the image path
image_path = '/home/matlab/Downloads/bug.jpg'

# --- 1. Open the color image ---
try:
    # Open the original color image
    img_color = Image.open(image_path)
except FileNotFoundError:
    print("Error: The image file was not found. Please check the file path.")
    exit()

# --- 2. Convert to a black and white (grayscale) image ---
# The 'L' mode converts the image to grayscale, using one channel (luminance).
img_grayscale = img_color.convert('L')
im_grayscale_array = np.asarray(img_grayscale)

# --- 3. Display the grayscale image and its histogram ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Display the grayscale image
ax1.imshow(im_grayscale_array, cmap='gray')
ax1.set_title('Grayscale Bug Image')
ax1.axis('off')  # Hide axes for cleaner image display

# Plot the histogram for the grayscale image
ax2.hist(im_grayscale_array.ravel(), bins=256, range=[0, 256], color='k', alpha=0.7)
ax2.set_title('Grayscale Pixel Intensity Histogram')
ax2.set_xlabel('Pixel Intensity (0=Black, 255=White)')
ax2.set_ylabel('Frequency (Number of Pixels)')
ax2.grid(True)

plt.tight_layout() # Adjusts subplot params for a tight layout
plt.show()
